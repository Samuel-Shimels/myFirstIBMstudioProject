# %% [markdown]
# # My Jupyter Notebook on IBM Watson Studio

# %% [markdown]
# **Samuel Shimels** <br>Data Analysis and Spreadsheet Automation Expert

# %% [markdown]
# *I am interested in data science because its power to support critical and strategic decisions in businesses. I'm passionate in exploring business operations and compositions, I believe which dominantly requires awareness on the data generated, what its is telling (the story, the insights).*

# %% [markdown]
# ### The following code prints "I like IBM data science certificate specialization"

# %%
print("I like IBM data science certificate specialization")
# Out:
# I like IBM data science certificate specialization

# %% [markdown]
# #### Horzontal rule <br> <hr/>

# %% [markdown]
# #### Unordered List<br>
# <ul><li>One
#     <li>Two
#     <li>Three</ul>

# %% [markdown]
# #### Ordered List<br>
# <ol>
# <li>One
# <li>Two
#     <li>Three
# </ol>

# %% [markdown]
# #### Images and Links<br>
# <a href = ‘images.html’> Images </a>
